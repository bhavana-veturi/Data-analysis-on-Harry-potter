# %%
from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt 
import pandas as pd

# %%
import nltk
from nltk.util import ngrams

from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')

books = list([1,2,3,4,5,6,7])

# %%
comment_words = ' '
stopwords = set(STOPWORDS)

# %%
for i in books:
    #book_name = "book_%s.txt" % (str(i))
    #book = open(os.path.join("book_%s.txt"%(str(i)))).read().lower()
    
    with open(('book_%s.txt' % (str(i))), 'r',encoding='utf-8') as file:
        contents = (file.read()).lower()
        book = (nltk.word_tokenize(contents))
    #print(book)
    for words in book: 
        comment_words = comment_words + words + ' '
    wordcloud = WordCloud(width = 800, height = 800,background_color ='white',stopwords = stopwords,min_font_size = 10).generate(comment_words)
    plt.figure(figsize = (8, 8), facecolor = None) 
    plt.imshow(wordcloud) 
    plt.axis("off") 
    plt.tight_layout(pad = 0) 
  
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-034a3fa36f21> in <module>()
#       8     #print(book)
#       9     for words in book:
# ---> 10         comment_words = comment_words + words + ' '
#      11     wordcloud = WordCloud(width = 800, height = 800,background_color ='white',stopwords = stopwords,min_font_size = 10).generate(comment_words)
#      12     plt.figure(figsize = (8, 8), facecolor = None)
#
# KeyboardInterrupt:

# %%
with open('book_2.txt', 'r',encoding='utf-8') as file:
        contents = (file.read()).lower()
        book = (nltk.word_tokenize(contents))
    #print(book)
for words in book: 
    comment_words = comment_words + words + ' '
wordcloud = WordCloud(width = 800, height = 800,background_color ='white',stopwords = stopwords,min_font_size = 10).generate(comment_words)
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %%
with open('book_3.txt', 'r',encoding='utf-8') as file:
        contents = (file.read()).lower()
        book = (nltk.word_tokenize(contents))
    #print(book)
for words in book: 
    comment_words = comment_words + words + ' '
wordcloud = WordCloud(width = 800, height = 800,background_color ='white',stopwords = stopwords,min_font_size = 10).generate(comment_words)
plt.figure(figsize = (6, 6), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %%
with open('book_4.txt', 'r',encoding='utf-8') as file:
        contents = (file.read()).lower()
        book = (nltk.word_tokenize(contents))
    #print(book)
for words in book: 
    comment_words = comment_words + words + ' '
wordcloud = WordCloud(width = 800, height = 800,background_color ='white',stopwords = stopwords,min_font_size = 10).generate(comment_words)
plt.figure(figsize = (5,5), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-f3f23806d7a2> in <module>()
#       4     #print(book)
#       5 for words in book:
# ----> 6     comment_words = comment_words + words + ' '
#       7 wordcloud = WordCloud(width = 800, height = 800,background_color ='white',stopwords = stopwords,min_font_size = 10).generate(comment_words)
#       8 plt.figure(figsize = (5,5), facecolor = None)
#
# KeyboardInterrupt:

# %%
with open('book_5.txt', 'r',encoding='utf-8') as file:
        contents = (file.read()).lower()
        book = (nltk.word_tokenize(contents))
    #print(book)
for words in book: 
    comment_words = comment_words + words + ' '
wordcloud = WordCloud(width = 800, height = 800,background_color ='white',stopwords = stopwords,min_font_size = 10).generate(comment_words)
plt.figure(figsize = (5,5), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %%
with open('book_6.txt', 'r',encoding='utf-8') as file:
        contents = (file.read()).lower()
        book = (nltk.word_tokenize(contents))
    #print(book)
for words in book: 
    comment_words = comment_words + words + ' '
wordcloud = WordCloud(width = 800, height = 800,background_color ='white',stopwords = stopwords,min_font_size = 10).generate(comment_words)
plt.figure(figsize = (5,5), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %%
with open('book_7.txt', 'r',encoding='utf-8') as file:
        contents = (file.read()).lower()
        book = (nltk.word_tokenize(contents))
    #print(book)
for words in book: 
    comment_words = comment_words + words + ' '
wordcloud = WordCloud(width = 800, height = 800,background_color ='white',stopwords = stopwords,min_font_size = 10).generate(comment_words)
plt.figure(figsize = (5,5), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()
